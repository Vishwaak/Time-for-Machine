# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("CREDIT CARD USERS DATA.csv")

# %%
df.describe()
# Out:
#            region       gender          age       agecat           ed  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      3.00140     0.503600    47.025600     4.238800    14.543000
# std       1.42176     0.500037    17.770338     1.308785     3.281083
# min       1.00000     0.000000    18.000000     2.000000     6.000000
# 25%       2.00000     0.000000    31.000000     3.000000    12.000000
# 50%       3.00000     1.000000    47.000000     4.000000    14.000000
# 75%       4.00000     1.000000    62.000000     5.000000    17.000000
# max       5.00000     1.000000    79.000000     6.000000    23.000000
#
#              edcat     jobcat       union       employ     empcat  \
# count  5000.000000  5000.0000  5000.00000  5000.000000  5000.0000
# mean      2.672000     2.7528     0.15120     9.730400     2.9326
# std       1.211738     1.7379     0.35828     9.690929     1.4533
# min       1.000000     1.0000     0.00000     0.000000     1.0000
# 25%       2.000000     1.0000     0.00000     2.000000     2.0000
# 50%       2.000000     2.0000     0.00000     7.000000     3.0000
# 75%       4.000000     4.0000     0.00000    15.000000     4.0000
# max       5.000000     6.0000     1.00000    52.000000     5.0000
#
#           ...             owncd       ownpda       ownpc      ownipod  \
# count     ...       5000.000000  5000.000000  5000.00000  5000.000000
# mean      ...          0.932800     0.201000     0.63280     0.479200
# std       ...          0.250393     0.400788     0.48209     0.499617
# min       ...          0.000000     0.000000     0.00000     0.000000
# 25%       ...          1.000000     0.000000     0.00000     0.000000
# 50%       ...          1.000000     0.000000     1.00000     0.000000
# 75%       ...          1.000000     0.000000     1.00000     1.000000
# max       ...          1.000000     1.000000     1.00000     1.000000
#
#            owngame       ownfax         news  response_01  response_02  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.474800     0.178800     0.472600     0.083600     0.129800
# std       0.499415     0.383223     0.499299     0.276815     0.336117
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     1.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        response_03
# count  5000.000000
# mean      0.102600
# std       0.303466
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 115 columns]

# %%
file = open("Output.csv" , "w")
file.write(df.describe().to_string())
# Out:
# 13643

# %%
for i in range(0,5000):
    if(df.lntollmon[i] == "#NULL!"):
        df.lntollmon[i] =  df.tollmon[i] + 1
# Out:
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(0,5000):
    if(df.lntollten[i] == "#NULL!"):
        df.lntollten[i] =  df.tollten[i] + 1
    if(df.lnequipmon[i] == "#NULL!"):
        df.lnequipmon[i] =  df.equipmon[i] + 1
    if(df.lnequipten[i] == "#NULL!"):
        df.lnequipten[i] =  df.equipten[i] + 1
    if(df.lncreddebt[i] == "#NULL!"):
        df.lncreddebt[i] =  df.creddebt[i] + 1
    if(df.lnlongmon[i] == "#NULL!"):
        df.lnlongmon[i] =  df.longmon[i] + 1
# Out:
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-7d298f41983d> in <module>
#       5         df.lnequipmon[i] =  df.equipmon[i] + 1
#       6     if(df.lnequipten[i] == "#NULL!"):
# ----> 7         df.lnequipten[i] =  df.equipten[i] + 1
#       8     if(df.lncreddebt[i] == "#NULL!"):
#       9         df.lncreddebt[i] =  df.creddebt[i] + 1
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     936
#     937         # do the setitem
# --> 938         cacher_needs_updating = self._check_is_chained_assignment_possible()
#     939         setitem(key, value)
#     940         if cacher_needs_updating:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    2625             if ref is not None and ref._is_mixed_type:
#    2626                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 2627                                          force=True)
#    2628             return True
#    2629         elif self._is_copy:
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2671             # the copy weakref
#    2672             try:
# -> 2673                 gc.collect(2)
#    2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#
# KeyboardInterrupt:

# %%
vars  = ["region",	"townsize",	"gender",	"age",	"agecat",	"ed",	"edcat",	"jobcat",	"union",	"employ",	
          "empcat",	"retire",	"income",	"lninc",	"inccat",	"debtinc",	"creddebt",	"lncreddebt",	"othdebt",
          "lnothdebt",	"default",	"jobsat",	"marital",	"spoused",	"spousedcat",	"reside",	"pets",	
          "pets_cats",	"pets_dogs",	"pets_birds",	"pets_reptiles",	"pets_small",	"pets_saltfish",	
          "pets_freshfish",	"homeown",	"hometype",	"address",	"addresscat",	"cars",	"carown",	"cartype",	
          "carvalue",	"carcatvalue",	"carbought",	"carbuy",	"commute",	"commutecat",	"commutetime",	
          "commutecar",	"commutemotorcycle",	"commutecarpool",	"commutebus",	"commuterail",	
          "commutepublic",	"commutebike",	"commutewalk",	"commutenonmotor",	"telecommute",	"reason",	
          "polview",	"polparty",	"polcontrib",	"vote",	"card",	"cardtype",	"cardbenefit",	"cardfee",	
          "cardtenure",	"cardtenurecat",	"card2",	"card2type",	"card2benefit",	"card2fee",	"card2tenure",	
          "card2tenurecat",	"carditems",	"cardspent",	"card2items",	"card2spent",	"active",	"bfast",	
          "tenure",	"churn",	"longmon",	"lnlongmon",	"longten",	"lnlongten",	"tollfree",	"tollmon",	
          "lntollmon",	"tollten",	"lntollten",	"equip",	"equipmon",	"lnequipmon",	"equipten",	
          "lnequipten",	"callcard",	"cardmon",	"lncardmon",	"cardten",	"lncardten",	"wireless",	
          "wiremon",	"lnwiremon",	"wireten",	"lnwireten",	"multline",	"voice",	"pager",	"internet",	
          "callid",	"callwait",	"forward",	"confer",	"ebill",	"owntv",	"hourstv",	"ownvcr",	"owndvd",	
          "owncd",	"ownpda",	"ownpc",	"ownipod",	"owngame",	"ownfax",	"news",	"response_01",	
"response_02", "response_03", "Total_spend"]

# %%
data = df.lncreddebt.fillna(-0.1304535)
df.lncreddebt = data
data = df.lnothdebt.fillna( 0.6969153)
df.lnothdebt = data
data = df.commutetime.fillna(25.3455382)
df.commutetime = data
data = df.longten.fillna(708.8717531)
df.longten = data
ddata = df.lnlongten.fillna(5.6112979)
df.lnlongten = data
data = df.cardtenure.fillna(720.4783914)
df.cardtenure = data
df.isna().sum()
# Out:
# custid            0
# region            0
# townsize          0
# gender            0
# age               0
# agecat            0
# birthmonth        0
# ed                0
# edcat             0
# jobcat            0
# union             0
# employ            0
# empcat            0
# retire            0
# income            0
# lninc             0
# inccat            0
# debtinc           0
# creddebt          0
# lncreddebt        0
# othdebt           0
# lnothdebt         0
# default           0
# jobsat            0
# marital           0
# spoused           0
# spousedcat        0
# reside            0
# pets              0
# pets_cats         0
#                ...
# cardten           2
# lncardten      1422
# wireless          0
# wiremon           0
# lnwiremon      3656
# wireten           0
# lnwireten      3656
# multline          0
# voice             0
# pager             0
# internet          0
# callid            0
# callwait          0
# forward           0
# confer            0
# ebill             0
# owntv             0
# hourstv           0
# ownvcr            0
# owndvd            0
# owncd             0
# ownpda            0
# ownpc             0
# ownipod           0
# owngame           0
# ownfax            0
# news              0
# response_01       0
# response_02       0
# response_03       0
# Length: 132, dtype: int64

# %%
df.Total_spend = df.card2spent + df.cardspent
# Out:
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
plt.hist(df.Total_spend)
df.ln_Total_spend = np.log(df.Total_spend)
# Out:
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
plt.hist(df.ln_Total_spend)
# Out:
# (array([   6.,   10.,   28.,  104.,  469., 1575., 1907.,  756.,  139.,
#            6.]),
#  array([2.09309787, 2.73309965, 3.37310142, 4.0131032 , 4.65310498,
#         5.29310675, 5.93310853, 6.57311031, 7.21311209, 7.85311386,
#         8.49311564]),
#  <a list of 10 Patch objects>)

# %%
from scipy import stats
count = 0;
for x in vars:
    f , p = stats.f_oneway(df.ln_Total_spend, df[x])
    print (count, "  " , f , "   " , p )
    count = int(count) + 1
# Out:
# 0    18199.938885066727     0.0
# 1    22111.14175871911     0.0
# 2    215605.01267054264     0.0
# 3    26609.857245169438     0.0
# 4    7177.692691645562     0.0
# 5    32524.571946372354     0.0
# 6    28876.475774965736     0.0
# 7    15200.034530175288     0.0
# 8    295412.77041135816     0.0
# 9    736.8520019150827     1.2569893743756773e-156
# 10    18370.537962869403     0.0
# 11    297071.3549868046     0.0
# 12    3875.5861716944682     0.0
# 13    26251.19602845123     0.0
# 14    33529.41830268173     0.0
# 15    1886.7737970117894     0.0
# 16    7084.932956093874     0.0
# 17    90748.3190966315     0.0
# 18    931.5902871857661     1.0498804651241887e-195
# 19    81583.88849272966     0.0
# 20    263848.7168967693     0.0
# 21    19593.281499920675     0.0
# 22    217561.9967096796     0.0
# 23    1.0299722723250992     0.31018973877056344
# 24    35813.26442265575     0.0
# 25    30114.384007802193     0.0
# 26    3553.9548748651423     0.0
# 27    126945.23092909149     0.0
# 28    145023.02887993003     0.0
# 29    249605.75785679757     0.0
# 30    317327.52403746743     0.0
# 31    223735.94429092426     0.0
# 32    264078.6667853531     0.0
# 33    8709.70807681156     0.0
# 34    210886.0260384091     0.0
# 35    66966.33625522308     0.0
# 36    3509.0854651008367     0.0
# 37    16981.201602441524     0.0
# 38    34674.480074445986     0.0
# 39    163269.87016098874     0.0
# 40    182819.46321899988     0.0
# 41    3290.082495841879     0.0
# 42    65642.23205220971     0.0
# 43    203253.6267665077     0.0
# 44    233364.73969273557     0.0
# 45    5659.6597322687685     0.0
# 46    39843.90331248346     0.0
# 47    53455.19251397777     0.0
# 48    211744.44212189034     0.0
# 49    320405.6093585335     0.0
# 50    252962.91505654555     0.0
# 51    226175.91537073872     0.0
# 52    252221.91454063673     0.0
# 53    324641.48730460805     0.0
# 54    308986.5468455415     0.0
# 55    229522.12531489987     0.0
# 56    349071.0916433391     0.0
# 57    279952.6353333783     0.0
# 58    1560.0855292916585     3.43304e-317
# 59    7702.101141134254     0.0
# 60    229906.79548385178     0.0
# 61    262541.6510629126     0.0
# 62    214572.26026620212     0.0
# 63    29125.022838184996     0.0
# 64    35871.38556352875     0.0
# 65    35954.8695495248     0.0
# 66    279260.999235797     0.0
# 67    3915.7017060359212     0.0
# 68    10781.53643962835     0.0
# 69    28482.878466325164     0.0
# 70    35157.10902947824     0.0
# 71    35375.45072298398     0.0
# 72    280261.8379773321     0.0
# 73    3000.1475152590097     0.0
# 74    12774.272355950172     0.0
# 75    7296.756850085455     0.0
# 76    9126.50354836126     0.0
# 77    1332.0993768829846     6.574806981735455e-274
# 78    5603.727537642468     0.0
# 79    218921.354983016     0.0
# 80    68238.42992454546     0.0
# 81    10087.983591223208     0.0
# 82    258123.47805096966     0.0
# 83    1705.394792357332     0.0
# 84    90748.3190966315     0.0
# 85    2577.256002246047     0.0
# 86    2577.256002246047     0.0
# 87    217987.96302337787     0.0
# 88    989.8796141004714     2.893350187275144e-207
# 89    nan     nan
# 90    1814.8236336555372     0.0
# 91    nan     nan
# 92    237135.37879263464     0.0
# 93    661.0200659522292     3.2518975722420455e-141
# 94    42386.10878603928     0.0
# 95    1294.5945646748169     1.0515508965858095e-266
# 96    5534.58369375908     0.0
# 97    213488.03676534834     0.0
# 98    1975.4429918462856     0.0
# 99    nan     nan
# 100    nan     nan
# 101    nan     nan
# 102    253767.02609059782     0.0
# 103    281.4059848496998     2.6265349949244638e-62
# 104    nan     nan
# 105    863.4769153964937     4.0598558961006575e-182
# 106    nan     nan
# 107    216836.50524092582     0.0
# 108    245200.97183261436     0.0
# 109    260956.48060320757     0.0
# 110    45181.61866060191     0.0
# 111    218025.65231942604     0.0
# 112    217671.79729165212     0.0
# 113    217525.6032587444     0.0
# 114    217764.00931249125     0.0
# 115    235637.10634524276     0.0
# 116    269282.21215091966     0.0
# 117    34301.87480316175     0.0
# 118    244843.98444062824     0.0
# 119    244269.46203278936     0.0
# 120    250101.93926176717     0.0
# 121    275081.09203904367     0.0
# 122    210893.73991440923     0.0
# 123    217653.4325456755     0.0
# 124    218063.44568357215     0.0
# 125    283577.00128646183     0.0
# 126    218273.172132614     0.0
# 127    331927.2819531657     0.0
# 128    305700.07540587895     0.0
# 129    320405.6093585335     0.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_spend'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-26a4ebb8c154> in <module>
#       2 count = 0;
#       3 for x in vars:
# ----> 4     f , p = stats.f_oneway(df.ln_Total_spend, df[x])
#       5     print (count, "  " , f , "   " , p )
#       6     count = int(count) + 1
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_spend'

# %%
count = 0
for i in range(0,5000):
    if(df.lntollten[i]  == "#NULL!"):
        df.lnlongten[i] = df.longten[i] + 1
# Out:
# /home/xerous/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
count = 0
for i in range(0,5000):
    if(df.[i]  == "#NULL!"):
        count = int(count) + 1
print(count)
# Out:
# 0

# %%
df['townsize'].fillna(1)
# Out:
# 0       2.0
# 1       5.0
# 2       4.0
# 3       3.0
# 4       2.0
# 5       4.0
# 6       5.0
# 7       4.0
# 8       3.0
# 9       2.0
# 10      1.0
# 11      4.0
# 12      2.0
# 13      2.0
# 14      1.0
# 15      1.0
# 16      1.0
# 17      2.0
# 18      5.0
# 19      1.0
# 20      3.0
# 21      4.0
# 22      1.0
# 23      4.0
# 24      3.0
# 25      3.0
# 26      4.0
# 27      1.0
# 28      1.0
# 29      3.0
#        ...
# 4970    2.0
# 4971    5.0
# 4972    1.0
# 4973    5.0
# 4974    3.0
# 4975    4.0
# 4976    1.0
# 4977    5.0
# 4978    1.0
# 4979    1.0
# 4980    1.0
# 4981    1.0
# 4982    3.0
# 4983    2.0
# 4984    3.0
# 4985    2.0
# 4986    1.0
# 4987    4.0
# 4988    2.0
# 4989    2.0
# 4990    3.0
# 4991    2.0
# 4992    4.0
# 4993    3.0
# 4994    1.0
# 4995    2.0
# 4996    3.0
# 4997    5.0
# 4998    1.0
# 4999    5.0
# Name: townsize, Length: 5000, dtype: float64

# %%
count = df.cardten.mean()
count
data = df.cardten.fillna(count)
df.cardten = data
df.cardten.isna().sum()
# Out:
# 0

# %%
for i in range(0,5000):
    if(df.lntollten[i] == "#NULL!"):
        df.lntollten[i] =  df.tollten[i] + 1
    if(df.lnequipmon[i] == "#NULL!"):
        df.lnequipmon[i] =  df.equipmon[i] + 1
    if(df.lnequipten[i] == "#NULL!"):
        df.lnequipten[i] =  df.equipten[i] + 1
    if(df.lncreddebt[i] == "#NULL!"):
        df.lncreddebt[i] =  df.creddebt[i] + 1
    if(df.lnlongmon[i] == "#NULL!"):
        df.lnlongmon[i] =  df.longmon[i] + 1

# %%
df.lnlongmon.isna().sum()
wine = (df.longmon) + 1
data = df.lncreddebt.fillna(wine)
df.lnlongmon = data

# %%
data = df.townsize.fillna(1)
df.townsize = data

# %%
df.isna().sum()
# Out:
# custid            0
# region            0
# townsize          0
# gender            0
# age               0
# agecat            0
# birthmonth        0
# ed                0
# edcat             0
# jobcat            0
# union             0
# employ            0
# empcat            0
# retire            0
# income            0
# lninc             0
# inccat            0
# debtinc           0
# creddebt          0
# lncreddebt        0
# othdebt           0
# lnothdebt         0
# default           0
# jobsat            0
# marital           0
# spoused           0
# spousedcat        0
# reside            0
# pets              0
# pets_cats         0
#                ...
# cardten           2
# lncardten      1422
# wireless          0
# wiremon           0
# lnwiremon      3656
# wireten           0
# lnwireten      3656
# multline          0
# voice             0
# pager             0
# internet          0
# callid            0
# callwait          0
# forward           0
# confer            0
# ebill             0
# owntv             0
# hourstv           0
# ownvcr            0
# owndvd            0
# owncd             0
# ownpda            0
# ownpc             0
# ownipod           0
# owngame           0
# ownfax            0
# news              0
# response_01       0
# response_02       0
# response_03       0
# Length: 132, dtype: int64
